# %% [markdown]
# # TABELAS CRIADAS NO AZURE DATABASE FOR MYSQL
#   - show tables;

# %% [markdown]
# ![mysql_tables.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # SELECIONAMENTO AS INFORMAÇÕES
#   - select count(*) from funcionario; # quantidades de linhas da tabela funcionario
#   - select count(*) from veiculo; # quantidades de linhas da tabela veiculo
#   - select * from funcionario limit 10; # selecionamento a tabela funcionario limitando a 10 linhas
#   - select * from veiculo limit 10; # selecionamento a tabela veiculo limitando a 10 linhas

# %% [markdown]
# #![select tables.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # CRIANDO A PIPELINE DE DADOS DENTRO DO DATA FACTORY PARA COPIAR OS ARQUIVOS DO AZURE DATABASE FOR MYSQL PARA O CONTAINER CRIADO NO AZURE BLOB STORAGE

# %% [markdown]
#   - ![pipeline1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # PIPELINE FINALIZADA

# %% [markdown]
#   ![pipeline2_completed.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # VISUALIZANDO OS ARQUIVOS COPIADOS DENTRO DO CONTEINER DO BLOB STORAGE

# %% [markdown]
# ![output_storage.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # VISUALIZANDO UM DOS ARQUIVOS COPIADOS

# %% [markdown]
# ![visual.jpg](data:image/jpeg;base64,...)
